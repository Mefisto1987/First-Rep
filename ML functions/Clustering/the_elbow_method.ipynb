# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.rcParams['figure.figsize'] = (16, 9)

X, y = make_blobs(n_samples=800, n_features=3, centers=4)

# %%
X
# Out:
# array([[-3.90975671, -5.39726485,  6.07772243],
#        [ 0.87710088,  6.15282634,  7.80810517],
#        [-1.19394847,  5.44406564,  8.01955453],
#        ...,
#        [-0.6632208 , -2.39824332, -6.64723626],
#        [-0.53811223,  7.11141558,  8.02665734],
#        [ 3.49047649, -2.86046463, -5.4947957 ]])

# %%
from sklearn.cluster import KMeans
wcss_list = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X)
    wcss_list.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), wcss_list)
plt.title("The elbow method")
plt.xlabel('Number of clusters')
plt.ylabel('wcss_list')
# Out:
# Text(0, 0.5, 'wcss_list')
